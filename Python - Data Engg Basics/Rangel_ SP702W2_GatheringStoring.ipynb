# %%
# !pip install pandas

# %%
import pandas as pd

path = r'D:\Users\MSI\Desktop\Sparta'
customer_data = pd.read_csv( path + '\Customer_v2.xls')
customer_data.columns
# Out:
# Index(['ID', 'Sex', 'Number_Children', 'Age', 'Income', 'Own_Car', 'Address',
#        'Credit_Bureau_Score', 'Buy_Car'],
#       dtype='object')

# %%
#1. The first 5 records from the file.
customer_data[0:5]
# Out:
#    ID     Sex  Number_Children  Age  Income Own_Car Address  \
# 0   1    Male                1   25   26000     Yes      QC
# 1   2    Male                2   37   42000      No      QC
# 2   3    Male                2   27   26500      No      QC
# 3   4    Male                3   56   77000     Yes  Manila
# 4   5  Female                4   30   32000      No  Manila
#
#    Credit_Bureau_Score Buy_Car
# 0                  650      No
# 1                  800     Yes
# 2                  650      No
# 3                  700     Yes
# 4                  300      No

# %%
#2. Data of customers that bought cars
customer_data[customer_data.Buy_Car == 'Yes']
# Out:
#     ID     Sex  Number_Children  Age  Income Own_Car   Address  \
# 1    2    Male                2   37   42000      No        QC
# 3    4    Male                3   56   77000     Yes    Manila
# 6    7  Female                3   45   55000      No    Taguig
# 7    8  Female                2   35   37000      No    Makati
# 8    9  Female                1   32   34000      No  Marikina
# 11  12    Male                4   26   28500      No        QC
# 12  13  Female                2   54   72000      No        QC
# 13  14  Female                3   48   58000      No    Taguig
# 17  18  Female                1   30   31500     Yes    Manila
#
#     Credit_Bureau_Score Buy_Car
# 1                   800     Yes
# 3                   700     Yes
# 6                   300     Yes
# 7                   550     Yes
# 8                   600     Yes
# 11                  300     Yes
# 12                  450     Yes
# 13                  500     Yes
# 17                  345     Yes

# %%
#3. Age, Income and number of children of customers who did not buy cars
data_nocar = customer_data[(customer_data.Buy_Car == 'No')]
data_nocar[['Age', 'Income', 'Number_Children']]
# Out:
#     Age  Income  Number_Children
# 0    25   26000                1
# 2    27   26500                2
# 4    30   32000                4
# 5    30   31500                5
# 9    28   28500                1
# 10   27   29000                2
# 14   29   31500                4
# 15   28   33000                2
# 16   30   32000                1
# 18   30   30000                1
# 19   30   32000                2

# %%
#4. Data of customers that bought cars and have income greater than 30,000.
data_yescar_inc = customer_data[(customer_data.Buy_Car == 'Yes') & (customer_data.Income > 30000)]
data_yescar_inc
# Out:
#     ID     Sex  Number_Children  Age  Income Own_Car   Address  \
# 1    2    Male                2   37   42000      No        QC
# 3    4    Male                3   56   77000     Yes    Manila
# 6    7  Female                3   45   55000      No    Taguig
# 7    8  Female                2   35   37000      No    Makati
# 8    9  Female                1   32   34000      No  Marikina
# 12  13  Female                2   54   72000      No        QC
# 13  14  Female                3   48   58000      No    Taguig
# 17  18  Female                1   30   31500     Yes    Manila
#
#     Credit_Bureau_Score Buy_Car
# 1                   800     Yes
# 3                   700     Yes
# 6                   300     Yes
# 7                   550     Yes
# 8                   600     Yes
# 12                  450     Yes
# 13                  500     Yes
# 17                  345     Yes

# %%
#5. Store data extracted from #4. in empty.xls file

data_yescar_inc.to_csv(r'D:\Users\MSI\Desktop\Sparta\empty.xls')
